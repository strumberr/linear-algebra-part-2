# %%
import numpy as np
import json_tricks
import scipy as sp
from types import SimpleNamespace
import matplotlib.pyplot as plt

# %%
answer = SimpleNamespace()

answer.A = np.array(
    [[1, 1],
     [-2, -1]]
)

answer.eig_values = np.array(
    [1j, -1j]
)

answer.eig_vectors = np.array(
    [[1/np.sqrt(3), 1/np.sqrt(3)],
     [(-1+1j)/np.sqrt(3), (-1-1j)/np.sqrt(3)]]
)

# %%
## Checking that matrix
## is recosntructed from eigenvalues and eigenvectors

V = answer.eig_vectors
L = np.diag(answer.eig_values)

print(V @ L @ np.linalg.inv(V))
# Out:
# [[ 1.+0.j  1.+0.j]
#  [-2.+0.j -1.+0.j]]

# %%
def general_solution(t, C):
    res = np.zeros([C.shape[0], t.shape[0]]).astype(complex)
    # --placeholder start--
    for k in range(len(answer.eig_values)):
        res += C[k] * np.exp(answer.eig_values[k] * t) * answer.eig_vectors[:, [k]]
    # --placeholder end--
    return res

# %%
## Visualizing the evolution of the state for some C
C = np.array([1, -2])
t = np.linspace(0, 10, 100)

res = general_solution(t, C).real
answer.general_solution = res

plt.plot(t, res[0, :])
plt.plot(t, res[1, :])
plt.legend(['carnivores', 'herbivores'])
plt.title('Population Dynamics')
# Out:
# Text(0.5, 1.0, 'Population Dynamics')

# %%
def solution_matrix_exponent(t, x0):
    res = np.zeros([x0.shape[0], t.shape[0]])
    ### YOUR CODE HERE ###

    return res

# %%
## Visualizing the evolution of the state for x0
x0 = np.array([100, 100])
t = np.linspace(0, 10, 100)

res = solution_matrix_exponent(t, x0).real
answer.solution_matrix_exponent = res

print(t.shape, res.shape)
plt.plot(t, res[0, :])
plt.plot(t, res[1, :])
plt.legend(['carnivores', 'herbivores'])
plt.title('Population Dynamics')
# Out:
# (100,) (2, 100)
# /tmp/ipykernel_77842/633713066.py:6: ComplexWarning: Casting complex values to real discards the imaginary part
#   res[:, index] = (
# Text(0.5, 1.0, 'Population Dynamics')

# %%
answer.coefficients = np.array(
    ### YOUR CODE HERE ###
)

# %%
## Visualizing for Cs for x0
C = answer.coefficients
t = np.linspace(0, 10, 100)

print(C.shape)
print(t.shape)

res = general_solution(t, C).real
answer.general_solution = res

plt.plot(t, res[0, :])
plt.plot(t, res[1, :])
plt.legend(['carnivores', 'herbivores'])
plt.title('Population Dynamics')
# Out:
# (2,)
# (100,)
# Text(0.5, 1.0, 'Population Dynamics')

# %%
json_tricks.dump(vars(answer), '.answer.json')
# Out:
# '{"A": {"__ndarray__": [[1, 1], [-1, 1]], "dtype": "int64", "shape": [2, 2], "Corder": true}, "eig_values": {"__ndarray__": [{"__complex__": [0.0, 1.0]}, {"__complex__": [-0.0, -1.0]}], "dtype": "complex128", "shape": [2]}, "eig_vectors": {"__ndarray__": [[{"__complex__": [1.0, 0.0]}, {"__complex__": [1.0, 0.0]}], [{"__complex__": [-1.0, 1.0]}, {"__complex__": [-1.0, -1.0]}]], "dtype": "complex128", "shape": [2, 2], "Corder": true}, "general_solution": {"__ndarray__": [[100.0, 119.65796563730395, 138.09609390450706, 155.1264197315427, 170.5753297048937, 184.28533194666926, 196.11666164481014, 205.94870586705636, 213.68123313359885, 219.23