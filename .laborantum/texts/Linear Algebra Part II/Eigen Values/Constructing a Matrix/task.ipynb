# %%
import numpy as np
import json_tricks
import scipy as sp

# %%
### NOTE: this is technichal 
### YOUR CODE HERE ###
# Out:
# '[{"ls": [9, 0], "vs": [{"__ndarray__": [[8, -10], [-5, 8], [4, -2], [2, 8]], "dtype": "int64", "shape": [4, 2], "Corder": false}, {"__ndarray__": [[-6, 4], [1, -10], [7, -6], [3, -5]], "dtype": "int64", "shape": [4, 2], "Corder": false}]}, {"ls": [2, 2], "vs": [{"__ndarray__": [[8, -8], [0, 8], [-1, -10], [0, 2], [-6, 7], [-10, 7], [2, 5], [-2, 6]], "dtype": "int64", "shape": [8, 2], "Corder": false}, {"__ndarray__": [[-9, -1, 4, -4, -3, -6], [-2, 8, -6, -5, 3, -2], [9, -3, 1, 2, 3, 3], [-8, -3, -7, -8, -9, 3], [-9, -10, 2, -7, 0, -2], [-3, -6, -8, -3, 8, -6], [3, -8, 5, 5, -6, -5], [3, -2, -6, 0, -2, -8]], "dtype": "int64", "shape": [8, 6], "Corder": false}]}, {"ls": [-5, 8], "vs": [{"__ndarray__": [[7], [7], [-5], [-6], [-2], [-1], [5], [2], [-2]], "dtype": "int64", "shape": [9, 1], "Corder": false}, {"__ndarray__": [[-5, -2, 6, 3, 7, 8, -1, 2], [-5, 4, 0, -2, 9, -6, 2, -5], [-8, 1, -1, 3, 1, -9, 6, 3], [1, 8, -7, -5, -7, 6, -7, 6], [-8, -1, -5, 6, 0, 1, -7, -7], [1, 6, 2, 9, 0, -7, 9, -3], [-10, -3, -10, -9, -4, 3, -2, -6], [-8, -4, -7, 5, -6, 7, -7, 2], [-2, -3, -1, -6, 2, 2, -7, -9]], "dtype": "int64", "shape": [9, 8], "Corder": false}]}, {"ls": [-10, -1], "vs": [{"__ndarray__": [[-5, -4, -4, -4, 7, 6, -7, -1], [-4, 6, 9, -1, -6, 4, 4, -3], [-9, -10, -1, 7, 8, -2, -2, 5], [6, 8, -1, 1, 5, 3, -2, 6], [-8, -8, 6, -6, -7, -10, 1, -4], [-6, 2, -5, -6, -8, 6, 7, -2], [-10, 0, 8, -5, -2, 5, -6, -5], [1, 5, -3, 1, 7, 8, 5, -1], [4, 7, -5, 7, 2, -7, 9, 7]], "dtype": "int64", "shape": [9, 8], "Corder": false}, {"__ndarray__": [[8], [-8], [7], [1], [8], [1], [-4], [1], [1]], "dtype": "int64", "shape": [9, 1], "Corder": false}]}, {"ls": [3, 4], "vs": [{"__ndarray__": [[-4, -2, 2], [3, 4, -5], [6, 1, 3], [4, -6, -7]], "dtype": "int64", "shape": [4, 3], "Corder": false}, {"__ndarray__": [[-9], [-8], [-3], [-5]], "dtype": "int64", "shape": [4, 1], "Corder": false}]}, {"ls": [3, 1], "vs": [{"__ndarray__": [[-1, -6], [-6, -9], [-8, -7]], "dtype": "int64", "shape": [3, 2], "Corder": false}, {"__ndarray__": [[-1], [5], [8]], "dtype": "int64", "shape": [3, 1], "Corder": false}]}, {"ls": [-9, -5, 4], "vs": [{"__ndarray__": [[-8, -2], [-8, 7], [-7, -10], [-4, 9]], "dtype": "int64", "shape": [4, 2], "Corder": false}, {"__ndarray__": [[5], [-4], [-1], [-4]], "dtype": "int64", "shape": [4, 1], "Corder": false}, {"__ndarray__": [[2], [-4], [-1], [7]], "dtype": "int64", "shape": [4, 1], "Corder": false}]}, {"ls": [-10, 7], "vs": [{"__ndarray__": [[4, 9, 3, 2], [4, -7, 3, 9], [-8, 7, 7, 6], [7, 3, -2, -1], [6, -9, 1, 0], [0, 1, -3, -1], [-5, -4, -7, 8]], "dtype": "int64", "shape": [7, 4], "Corder": false}, {"__ndarray__": [[-8, 7, 4], [4, -8, 7], [-3, 4, 5], [1, -3, -2], [7, 5, -9], [-4, -4, 0], [5, -10, -6]], "dtype": "int64", "shape": [7, 3], "Corder": false}]}, {"ls": [4, 9], "vs": [{"__ndarray__": [[9], [-7], [-8], [-6]], "dtype": "int64", "shape": [4, 1], "Corder": false}, {"__ndarray__": [[-7, -6, 0], [4, -8, -8], [-5, -3, 6], [-1, 8, 7]], "dtype": "int64", "shape": [4, 3], "Corder": false}]}, {"ls": [2, -3, 7], "vs": [{"__ndarray__": [[5, 7], [-4, 7], [-1, 9], [-3, -1]], "dtype": "int64", "shape": [4, 2], "Corder": false}, {"__ndarray__": [[-3], [-9], [-10], [-1]], "dtype": "int64", "shape": [4, 1], "Corder": false}, {"__ndarray__": [[-2], [0], [-6], [6]], "dtype": "int64", "shape": [4, 1], "Corder": false}]}, {"ls": [-10, -6, 4], "vs": [{"__ndarray__": [[8, -1, -4, 8], [-5, 2, -10, 7], [2, 1, 8, -9], [-8, 0, -5, -9], [-5, 1, -8, -6], [4, -10, 3, 1], [2, 4, -8, -9]], "dtype": "int64", "shape": [7, 4], "Corder": false}, {"__ndarray__": [[7, -4], [-6, 5], [4, -10], [9, 3], [-2, -8], [4, -10], [3, 5]], "dtype": "int64", "shape": [7, 2], "Corder": false}, {"__ndarray__": [[-4], [-2], [-6], [8], [-5], [1], [9]], "dtype": "int64", "shape": [7, 1], "Corder": false}]}, {"ls": [-4, 7], "vs": [{"__ndarray__": [[7, 4], [2, -9], [-7, 6]], "dtype": "int64", "shape": [3, 2], "Corder": false}, {"__ndarray__": [[-5], [5], [-3]], "dtype": "int64", "shape":  ...

# %%
def build_matrix(ls, vs):
    J = []
    S = []

    ### YOUR CODE HERE ###

    return J, S, S @ J @ np.linalg.inv(S)

# %%
inputs = json_tricks.load('inputs.json')

results = []
for input in inputs:
    res = build_matrix(**input)
    results.append(res)

json_tricks.dump(results, '.answer.json');
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[5], line 5
#       3 results = []
#       4 for input in inputs:
# ----> 5     res = build_matrix(**input)
#       6     results.append(res)
#       8 json_tricks.dump(results, '.answer.json');
#
# Cell In[4], line 16, in build_matrix(ls, vs)
#      14     start += k
#      15 S = np.column_stack(S_list)
# ---> 16 return J, S, S @ J @ np.linalg.inv(S)
#
# File /usr/local/lib/python3.11/site-packages/numpy/linalg/_linalg.py:609, in inv(a)
#     607 a, wrap = _makearray(a)
#     608 _assert_stacked_2d(a)
# --> 609 _assert_stacked_square(a)
#     610 t, result_t = _commonType(a)
#     612 signature = 'D->D' if isComplexType(t) else 'd->d'
#
# File /usr/local/lib/python3.11/site-packages/numpy/linalg/_linalg.py:202, in _assert_stacked_square(*arrays)
#     200 m, n = a.shape[-2:]
#     201 if m != n:
# --> 202     raise LinAlgError('Last 2 dimensions of the array must be square')
#
# LinAlgError: Last 2 dimensions of the array must be square
