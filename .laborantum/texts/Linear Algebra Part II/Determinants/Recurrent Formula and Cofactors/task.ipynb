# %%
import numpy as np
import json_tricks

# %%
answer = {
    'task1': {
        'C1': np.array(
            [[1], [0],[0],[-2]]
        ),
        'det': (
                -1
        )
    },
    'task2': {
        # i am pretty sure this is correct. Ask Mike.
        'C1': np.array([
                [1],
                [-1],
                [0],
                [-1]
        ]),
        'det': (
            -1
        )
    }
}

# %%
json_tricks.dump(answer, '.answer.json')
