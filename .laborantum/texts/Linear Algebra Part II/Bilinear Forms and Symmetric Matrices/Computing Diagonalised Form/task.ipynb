# %%
import numpy as np
import scipy as sp
import json_tricks

# %%
### YOUR CODE HERE ###

# %%
def diagonalize(A):
    ### YOUR CODE HERE ###
    return Lambda, Q, D, L, definiteness

# %%
inputs = json_tricks.load('inputs.json')

outputs = []

for input in inputs:
    outputs.append(diagonalize(**input))

json_tricks.dump(outputs, '.answer.json')
