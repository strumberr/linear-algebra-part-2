# %%
import numpy as np
import json_tricks

# %%
### YOUR CODE HERE ###

# %%
answer = {
    'task1': {
        'canonical': {
            'det(A - lI)': [
                ### YOUR CODE HERE ###            ],
            'Lambda': np.array(
                ### YOUR CODE HERE ###            ),
            'Q': np.array(
                ### YOUR CODE HERE ###            ),
            'C': np.array([
                ### YOUR CODE HERE ###            ]),
            'd': np.array(
                ### YOUR CODE HERE ###            )
        },
        'LDL': {
            'D': np.array([
                ### YOUR CODE HERE ###            ]),
            'L': np.array(
                ### YOUR CODE HERE ###            ),
            'C': np.array([
                ### YOUR CODE HERE ###            ]),
            'd': np.array([
                ### YOUR CODE HERE ###            ]),
            'definitiness': str(
                ### YOUR CODE HERE ###            )
        },
        'dets':{
            '1x1': [
                ### YOUR CODE HERE ###            ],
            '2x2': [
                ### YOUR CODE HERE ###            ],
            'definiteness': str(
                ### YOUR CODE HERE ###            )
        }
    },
    'task2': {
        'canonical': {
            'det(A - lI)': [
                ### YOUR CODE HERE ###            ],
            'Lambda': np.array(
                ### YOUR CODE HERE ###            ),
            'Q': np.array(
                ### YOUR CODE HERE ###            ),
            'C': np.array([
                ### YOUR CODE HERE ###            ]),
            'd': np.array(
                ### YOUR CODE HERE ###            )
        },
        'LDL': {
            'D': np.array([
                ### YOUR CODE HERE ###            ]),
            'L': np.array(
                ### YOUR CODE HERE ###            ),
            'C': np.array([
                ### YOUR CODE HERE ###            ]),
            'd': np.array([
                ### YOUR CODE HERE ###            ]),
            'definitiness': str(
                ### YOUR CODE HERE ###            )
        },
        'dets':{
            '1x1': [
                ### YOUR CODE HERE ###            ],
            '2x2': [
                ### YOUR CODE HERE ###            ],
            'definiteness': str(
                ### YOUR CODE HERE ###            )
        }
    },
    'task3': {
        'canonical': {
            'det(A - lI)': [
                ### YOUR CODE HERE ###            ],
            'Lambda': np.array(
                ### YOUR CODE HERE ###            ),
            'Q': np.array(
                ### YOUR CODE HERE ###            ),
            'C': np.array([
                ### YOUR CODE HERE ###            ]),
            'd': np.array(
                ### YOUR CODE HERE ###            )
        },
        'LDL': {
            'D': np.array([
                ### YOUR CODE HERE ###            ]),
            'L': np.array(
                ### YOUR CODE HERE ###            ),
            'C': np.array([
                ### YOUR CODE HERE ###            ]),
            'd': np.array([
                ### YOUR CODE HERE ###            ]),
            'definitiness': str(
                ### YOUR CODE HERE ###            )
        },
        'dets':{
            '1x1': [
                ### YOUR CODE HERE ###            ],
            '2x2': [
                ### YOUR CODE HERE ###            ],
            '3x3': [
                ### YOUR CODE HERE ###            ],
            'definiteness': str(
                ### YOUR CODE HERE ###            )
        }
    },
}

json_tricks.dump(answer, '.answer.json')
