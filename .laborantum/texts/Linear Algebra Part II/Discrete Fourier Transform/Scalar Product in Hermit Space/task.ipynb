# %%
import numpy as np
import json_tricks

# %%
answer = {
    'task1':{
        '||u||': complex(
            ### YOUR CODE HERE ###        ),
        '||v||': complex(
            ### YOUR CODE HERE ###        ),
        '<u, v>': complex(
            ### YOUR CODE HERE ###        ),
        'cos': complex(
            ### YOUR CODE HERE ###        ),
    },
    'task2':{
        '||u||': complex(
            ### YOUR CODE HERE ###        ),
        '||v||': complex(
            ### YOUR CODE HERE ###        ),
        '<u, v>': complex(
            ### YOUR CODE HERE ###        ),
        'cos': complex(
            ### YOUR CODE HERE ###        ),
    },
    'task3':{
        '||u||': complex(
            ### YOUR CODE HERE ###        ),
        '||v||': complex(
            ### YOUR CODE HERE ###        ),
        '<u, v>': complex(
            ### YOUR CODE HERE ###        ),
        'cos': complex(
            ### YOUR CODE HERE ###        ),
    },
}

json_tricks.dump(answer, '.answer.json')
